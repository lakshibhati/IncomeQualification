# %%
# Import the library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the dataset
df_train=pd.read_csv('train.csv')
df_test=pd.read_csv('test.csv')

# %%
df_train.head()
# Out:
#              Id      v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  v18q1  \
# 0  ID_279628684  190000.0       0      3       0     1       1     0    NaN
# 1  ID_f29eb3ddd  135000.0       0      4       0     1       1     1    1.0
# 2  ID_68de51c94       NaN       0      8       0     1       1     0    NaN
# 3  ID_d671db89c  180000.0       0      5       0     1       1     1    1.0
# 4  ID_d56d6f5f5  180000.0       0      5       0     1       1     1    1.0
#
#    r4h1  ...  SQBescolari  SQBage  SQBhogar_total  SQBedjefe  SQBhogar_nin  \
# 0     0  ...          100    1849               1        100             0
# 1     0  ...          144    4489               1        144             0
# 2     0  ...          121    8464               1          0             0
# 3     0  ...           81     289              16        121             4
# 4     0  ...          121    1369              16        121             4
#
# ...

# %%
df_test.head()
# Out:
#              Id      v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  v18q1  \
# 0  ID_2f6873615       NaN       0      5       0     1       1     0    NaN
# 1  ID_1c78846d2       NaN       0      5       0     1       1     0    NaN
# 2  ID_e5442cf6a       NaN       0      5       0     1       1     0    NaN
# 3  ID_a8db26a79       NaN       0     14       0     1       1     1    1.0
# 4  ID_a62966799  175000.0       0      4       0     1       1     1    1.0
#
#    r4h1  ...  age  SQBescolari  SQBage  SQBhogar_total  SQBedjefe  \
# 0     1  ...    4            0      16               9          0
# 1     1  ...   41          256    1681               9          0
# 2     1  ...   41          289    1681               9          0
# 3     0  ...   59          256    3481               1        256
# 4     0  ...   18          121     324               1          0
#
#    SQBhogar_nin  SQBovercrowding  SQBdependency  SQBmeaned  agesq
# ...

# %% [markdown]
# ## Target is the output variable

# %% [markdown]
# ## Understand the type of data.

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9557 entries, 0 to 9556
# Columns: 143 entries, Id to Target
# dtypes: float64(8), int64(130), object(5)
# memory usage: 10.4+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23856 entries, 0 to 23855
# Columns: 142 entries, Id to agesq
# dtypes: float64(8), int64(129), object(5)
# memory usage: 25.8+ MB

# %% [markdown]
# ### Check if there are any biases in your dataset.

# %%
for c in df_train.columns:
    #print("column values: ",c)
    cardinality = len(np.unique(df_train[c]))
    #print(cardinality)

    if cardinality == 1:
        print(c)
        #df_train.drop(c, axis=1) 

        #df_test.drop(c, axis=1)
# Out:
# elimbasu5

# %%
df_train.drop("elimbasu5", axis=1, inplace=True) #dropped the column because the variance is equal to zero

# %% [markdown]
# #### elimbasu5 is biase in the training data set

# %%
for d in df_test.columns:
    #print("column values: ",c)
    cardinality = len(np.unique(df_test[d]))
    #print(cardinality)

    if cardinality == 1:
        print(d)
        #df_train.drop(c, axis=1) 

        #df_test.drop(c, axis=1)

# %%
df_test.drop("elimbasu5", axis=1, inplace=True) #dropped the column because the variance is equal to zero

# %%
temp = df_train.isnull().sum();

columns = df_train.columns
count = 0;
for i in range(len(temp)):
    if(temp[i] > 0):
        print(columns[i])
        count += 1;
        
if(count == 0):
    print("No null value found in any columns");
# Out:
# v2a1
# v18q1
# rez_esc
# meaneduc
# SQBmeaned

# %%
df_train.dropna(inplace=True)
# Out:
#                 Id      v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  \
# 3     ID_d671db89c  180000.0       0      5       0     1       1     1
# 6     ID_e9e0c1100  180000.0       0      5       0     1       1     1
# 75    ID_dd93e20ec  350000.0       0      6       0     1       1     1
# 130   ID_651377e3e  260000.0       0      5       0     1       1     1
# 133   ID_272bdf973  260000.0       0      5       0     1       1     1
# ...            ...       ...     ...    ...     ...   ...     ...   ...
# 8991  ID_6edc54f34  100000.0       0      6       0     1       1     1
# 9037  ID_b7815bb34  150000.0       0      7       0     1       1     1
# 9039  ID_6019368cd  150000.0       0      7       0     1       1     1
# 9066  ID_cec76e220   40000.0       0      4       0     1       1     1
# 9213  ID_9750f0adc  100000.0       0      6       0     1       1     1
#
#       v18q1  r4h1  ...  SQBescolari  SQBage  SQBhogar_total  SQBedjefe  \
# ...

# %%
#df_train.drop(['v2a1','v18q1','rez_esc','meaneduc','SQBmeaned'], axis=1, inplace=True) # dropping null

# %%
df_train.isna().sum()
# Out:
# Id                    0
# v2a1               6860
# hacdor                0
# rooms                 0
# hacapo                0
#                    ...
# SQBovercrowding       0
# SQBdependency         0
# SQBmeaned             5
# agesq                 0
# Target                0
# Length: 142, dtype: int64

# %%
df_train.isnull().sum()
# Out:
# Id                    0
# v2a1               6860
# hacdor                0
# rooms                 0
# hacapo                0
#                    ...
# SQBovercrowding       0
# SQBdependency         0
# SQBmeaned             5
# agesq                 0
# Target                0
# Length: 143, dtype: int64

# %%
df_train.apply(lambda x: sum(x.isnull()))
# Out:
# Id                    0
# v2a1               6860
# hacdor                0
# rooms                 0
# hacapo                0
#                    ...
# SQBovercrowding       0
# SQBdependency         0
# SQBmeaned             5
# agesq                 0
# Target                0
# Length: 143, dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Id                     0
# v2a1               17403
# hacdor                 0
# rooms                  0
# hacapo                 0
#                    ...
# SQBhogar_nin           0
# SQBovercrowding        0
# SQBdependency          0
# SQBmeaned             31
# agesq                  0
# Length: 142, dtype: int64

# %%
temp = df_test.isnull().sum();
columns = df_test.columns
count = 0;
for i in range(len(temp)):
    if(temp[i] > 0):
        print(columns[i])
        count += 1;
        
if(count == 0):
    print("No null value found in any columns");
# Out:
# v2a1
# v18q1
# rez_esc
# meaneduc
# SQBmeaned

# %%
df_train[df_train.duplicated()]
# Out:
# Empty DataFrame
# ...

# %%
df_test[df_test.duplicated()]
# Out:
# Empty DataFrame
# ...

# %%
#Filter categorical variables
categorical_columns = [x for x in df_train.dtypes.index if df_train.dtypes[x]=='object']
#Exclude ID cols:
categorical_columns = [x for x in categorical_columns if x not in ['Id','idhogar']]
#Print frequency of categories
for col in categorical_columns:
    print ('\nFrequency of Categories for varible %s'%col)
    print (df_train[col].value_counts())
# Out:
# Frequency of Categories for varible dependency
# yes          2192
# no           1747
# .5           1497
# 2             730
# 1.5           713
# .33333334     598
# .66666669     487
# 8             378
# .25           260
# 3             236
# 4             100
# .75            98
# .2             90
# .40000001      84
# 1.3333334      84
# 2.5            77
# 5              24
# 1.25           18
# 3.5            18
# .80000001      18
# 2.25           13
# .71428573      12
# 1.75           11
# 1.2            11
# .83333331      11
# .22222222      11
# .2857143        9
# 1.6666666       8
# .60000002       8
# 6               7
# .16666667       7
# Name: dependency, dtype: int64
#
# Frequency of Categories for varible edjefe
# no     3762
# 6      1845
# 11      751
# 9       486
# 3       307
# 15      285
# 8       257
# 7       234
# 5       222
# 14      208
# 17      202
# 2       194
# 4       137
# 16      134
# yes     123
# 12      113
# 10      111
# ...

# %%
df_train[['idhogar']]
# Out:
#         idhogar
# 0     21eb7fcc1
# 1     0e5d7a658
# 2     2c7317ea8
# 3     2b58d945f
# 4     2b58d945f
# ...         ...
# 9552  d6c086aa3
# 9553  d6c086aa3
# 9554  d6c086aa3
# 9555  d6c086aa3
# 9556  d6c086aa3
#
# [9557 rows x 1 columns]

# %%
df_train[['dependency']]
# Out:
#      dependency
# 0            no
# 1             8
# 2             8
# 3           yes
# 4           yes
# ...         ...
# 9552        .25
# 9553        .25
# 9554        .25
# 9555        .25
# 9556        .25
#
# [9557 rows x 1 columns]

# %%
df_test.describe()
# Out:
#                v2a1        hacdor         rooms        hacapo          v14a  \
# count  6.453000e+03  23856.000000  23856.000000  23856.000000  23856.000000
# mean   1.748726e+05      0.050679      4.955776      0.028421      0.992748
# std    1.567887e+05      0.219346      1.539753      0.166174      0.084850
# min    0.000000e+00      0.000000      1.000000      0.000000      0.000000
# 25%    8.000000e+04      0.000000      4.000000      0.000000      1.000000
# 50%    1.400000e+05      0.000000      5.000000      0.000000      1.000000
# 75%    2.200000e+05      0.000000      6.000000      0.000000      1.000000
# max    2.852700e+06      1.000000     15.000000      1.000000      1.000000
#
#              refrig          v18q        v18q1          r4h1          r4h2  \
# count  23856.000000  23856.000000  5730.000000  23856.000000  23856.000000
# mean       0.961603      0.240191     1.348517      0.416541      1.563967
# ...

# %%
df_train.dependency.unique()
# Out:
# array(['no', '8', 'yes', '3', '.5', '.25', '2', '.66666669', '.33333334',
#        '1.5', '.40000001', '.75', '1.25', '.2', '2.5', '1.2', '4',
#        '1.3333334', '2.25', '.22222222', '5', '.83333331', '.80000001',
#        '6', '3.5', '1.6666666', '.2857143', '1.75', '.71428573',
#        '.16666667', '.60000002'], dtype=object)

# %% [markdown]
# #### elimbasu5 is biase in the test data set

# %%
 from sklearn.preprocessing import StandardScaler

# %%
# Initialise the Scaler
scaler = StandardScaler()
 
# To scale data
scaler.fit(df_train)
scaler.fit(df_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/vl/ds4939js6cn74f1bkm98d0fm0000gn/T/ipykernel_45986/1755527598.py in <module>
#       3
#       4 # To scale data
# ----> 5 scaler.fit(df_train)
#       6 scaler.fit(df_test)
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
#     807
#     808     def partial_fit(self, X, y=None, sample_weight=None):
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y, sample_weight)
#     839         """
#     840         first_call = not hasattr(self, "n_samples_seen_")
# --> 841         X = self._validate_data(
#     842             X,
# ...

# %% [markdown]
# ## Check whether all members of the house have the same poverty level.

# %% [markdown]
# #idhogar is unique identifiere for each house hold. Hence for house hold level analysis this feature will be consider

# %% [markdown]
# 1 Extreme poverty
# 2 moderate poverty
# 3 vunarable house hold
# 4 non vunerable house hold

# %%
# house holde with same poverty level
poverty_equal = df_train.groupby('idhogar')['Target'].apply(lambda X:X.unique()==1)

# house holde with unequal poverty level
poverty_unequal = poverty_equal[poverty_equal!=True]

print("The household where all the family members of the house do not have same poverty level", len(poverty_unequal))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/vl/ds4939js6cn74f1bkm98d0fm0000gn/T/ipykernel_47643/1838002571.py in <module>
#       3
#       4 # house holde with unequal poverty level
# ----> 5 poverty_unequal = poverty_equal[poverty_equal!=True]
#       6
#       7 print("The household where all the family members of the house do not have same poverty level", len(poverty_unequal))
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py in __ne__(self, other)
#      42     @unpack_zerodim_and_defer("__ne__")
#      43     def __ne__(self, other):
# ...
